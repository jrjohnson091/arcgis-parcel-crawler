# %%
import pandas as pd
from sqlalchemy import select

from app.config import settings
from app.db import get_session
from app.models import Attributes, NearbyParcelIdsParams
from app.nearby_parcel_request import fetch_nearby_ids

params = NearbyParcelIdsParams(
    lon=-79.9513103495131,
    lat=32.706641645949055,
    distance=5.0,
)

nearby = fetch_nearby_ids(params)

len(nearby.objectIds), nearby.objectIds[:10]
# Out:
# (1364,
#  [67185,
#   195460,
#   157919,
#   127540,
#   115446,
#   171556,
#   156568,
#   118340,
#   194249,
#   134063])

# %%
session = next(get_session())

stmt = select(Attributes).where(
    Attributes.objectid.in_(nearby.objectIds)
)

rows = session.scalars(stmt).all()

# %%
df = pd.DataFrame(
    [
        {
            column.name: getattr(row, column.name)
            for column in Attributes.__table__.columns
        }
        for row in rows
    ]
)

df.head()
# Out:
#     id  objectid         pid                  owner1              owner2  \
# 0  243       243  4260300064  WALTHALL LEONIDAS N IV   WALTHALL OLIVIA H
# 1  308       308  4261600058     WATERS WILBERT T JR  WATERS ELIZABETH P
# 2  391       391  4261100295          RIGSBY MELISSA     RIGSBY JOSEPH M
# 3  483       483  4261100303   JDR75 INVESTMENTS LLC                 NaN
# 4  716       716  4260800089         BENNETT BRYAN B   BENNETT JESSICA W
#
#   tax_district       class_code mail_st_no    mail_st_name mail_st_type  ...  \
# 0          3-8  101 - RESID-SFR        680       GREGG  DR          NaN  ...
# 1          3-4  101 - RESID-SFR        681  OLD PLANTATION           RD  ...
# 2          3-4  101 - RESID-SFR        309          BOUNTY           LN  ...
# 3          3-4  101 - RESID-SFR       2820   SEVEN SHIELDS           LN  ...
# 4          3-4  101 - RESID-SFR        968     WHITE POINT         BLVD  ...
#
#     subdivision acreage legal_residence other agr deed_book_page  \
# 0  LAWTON BLUFF    0.46               Y     N   N       0933-959
# 1           NaN    0.00               Y     N   N       A150-129
# 2           NaN    0.22               Y     N   N       0647-938
# 3           NaN    0.22               Y     N   N       1244-442
# 4           NaN    0.00               Y     N   N       0570-223
#
#   plat_book_page sale_price  recorded_date   doc_date
# 0      S20- 0025   220000.0     2020-11-10 2020-10-30
# 1          AY-56   108000.0     1985-12-03 1985-11-27
# 2         EE-738   499000.0     2017-06-27 2017-06-22
# 3         EE-738   925000.0     2024-05-13 2024-05-01
# 4          AH-71   395000.0     2016-07-22 2016-07-20
#
# [5 rows x 27 columns]
